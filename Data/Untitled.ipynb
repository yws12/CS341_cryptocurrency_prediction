# %%
import pandas as pd

# %%
df = pd.read_pickle('df_hourly_BTC_with_pred_shift.pickle')

# %%
df.head()
# Out:
#                      USDT_BTC_high  USDT_BTC_low  USDT_BTC_close  \
# time
# 2016-01-03 01:00:00     436.949900      436.9499      436.949900
# 2016-01-03 02:00:00     436.949900      432.3100      435.614998
# 2016-01-03 03:00:00     435.614998      430.4900      430.490000
# 2016-01-03 04:00:00     431.450000      430.4900      430.490000
# 2016-01-03 05:00:00     435.127280      429.0000      435.127280
#
#                      USDT_BTC_open  USDT_BTC_volume  USDT_BTC_quoteVolume  \
# time
# 2016-01-03 01:00:00     436.949900         0.000000              0.000000
# 2016-01-03 02:00:00     436.949900         7.644967              0.017558
# 2016-01-03 03:00:00     435.614998        73.240291              0.170000
# 2016-01-03 04:00:00     430.490000        30.883032              0.071724
# 2016-01-03 05:00:00     430.490000        63.109290              0.145745
#
#                      USDT_BTC_weighted_mean  USDT_BTC_volatility  \
# time
# ...

# %%
df.columns
# Out:
# Index(['USDT_BTC_high', 'USDT_BTC_low', 'USDT_BTC_close', 'USDT_BTC_open',
#        'USDT_BTC_volume', 'USDT_BTC_quoteVolume', 'USDT_BTC_weighted_mean',
#        'USDT_BTC_volatility', 'USDT_BTC_pctChange', 'USDT_ETH_high',
#        'USDT_ETH_low', 'USDT_ETH_close', 'USDT_ETH_open', 'USDT_ETH_volume',
#        'USDT_ETH_quoteVolume', 'USDT_ETH_weighted_mean', 'USDT_ETH_volatility',
#        'USDT_ETH_pctChange', 'USDT_LTC_high', 'USDT_LTC_low', 'USDT_LTC_close',
#        'USDT_LTC_open', 'USDT_LTC_volume', 'USDT_LTC_quoteVolume',
#        'USDT_LTC_weighted_mean', 'USDT_LTC_volatility', 'USDT_LTC_pctChange',
#        'USDT_XRP_high', 'USDT_XRP_low', 'USDT_XRP_close', 'USDT_XRP_open',
#        'USDT_XRP_volume', 'USDT_XRP_quoteVolume', 'USDT_XRP_weighted_mean',
#        'USDT_XRP_volatility', 'USDT_XRP_pctChange', 'BTC_ETH_high',
#        'BTC_ETH_low', 'BTC_ETH_close', 'BTC_ETH_open', 'BTC_ETH_volume',
#        'BTC_ETH_quoteVolume', 'BTC_ETH_weighted_mean', 'BTC_ETH_volatility',
# ...

# %%
df17 = df[8500:]

# %%
df17.max().to_frame()
# Out:
#                                            0
# USDT_BTC_high                   1.990344e+04
# USDT_BTC_low                    1.968410e+04
# USDT_BTC_close                  1.977500e+04
# USDT_BTC_open                   1.979900e+04
# USDT_BTC_volume                 4.665785e+07
# USDT_BTC_quoteVolume            6.163265e+03
# USDT_BTC_weighted_mean          1.976345e+04
# USDT_BTC_volatility             3.917235e-02
# USDT_BTC_pctChange              9.932745e-02
# USDT_ETH_high                   1.424000e+03
# USDT_ETH_low                    1.395000e+03
# USDT_ETH_close                  1.422470e+03
# USDT_ETH_open                   1.418700e+03
# USDT_ETH_volume                 1.509291e+07
# USDT_ETH_quoteVolume            6.363661e+04
# USDT_ETH_weighted_mean          1.410275e+03
# USDT_ETH_volatility             7.103284e-02
# USDT_ETH_pctChange              1.248481e-01
# USDT_LTC_high                   3.706604e+02
# USDT_LTC_low                    3.600000e+02
# ...

# %%
df17.min().to_frame()
# Out:
#                                          0
# USDT_BTC_high                   767.207999
# USDT_BTC_low                    751.000000
# USDT_BTC_close                  757.000000
# USDT_BTC_open                   756.770000
# USDT_BTC_volume                   0.000000
# USDT_BTC_quoteVolume              0.000000
# USDT_BTC_weighted_mean          758.740122
# USDT_BTC_volatility               0.000000
# USDT_BTC_pctChange               -0.142961
# USDT_ETH_high                     7.124311
# USDT_ETH_low                      7.000000
# USDT_ETH_close                    7.010000
# USDT_ETH_open                     7.010000
# USDT_ETH_volume                   0.000000
# USDT_ETH_quoteVolume              0.000000
# USDT_ETH_weighted_mean            7.053805
# USDT_ETH_volatility               0.000000
# USDT_ETH_pctChange               -0.162392
# USDT_LTC_high                     3.641900
# USDT_LTC_low                      2.910000
# USDT_LTC_close                    3.591000
# ...

# %%
df = df.fillna(method='ffill')

# %%
df.to_pickle('df_hourly_BTC_with_pred_shift.pickle')
