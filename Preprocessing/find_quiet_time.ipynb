# %%
__author__ = "Kexin Yu"
__version__ = "CS341, Stanford, Spring 2018"

# %%
import pandas as pd
df_BTC = pd.read_pickle('BTC-USD-60.pkl')

import datetime
df_BTC['date'] = pd.to_datetime(df_BTC['time'],unit='s').dt.date
df_BTC['datetime'] = pd.to_datetime(df_BTC['time'],unit='s').dt.time
df_BTC['hour'] = pd.to_datetime(df_BTC['time'],unit='s').dt.hour
Daily_BTC = df_BTC.groupby('date')

quiet_hours_BTC = Daily_BTC.apply(lambda x: x.loc[x['volume'] == x['volume'].min()])['hour'].values.tolist()
#quiet_time_BTC = Daily_BTC.apply(lambda x: x.loc[x['volume'] == x['volume'].min()])['datetime'].values.tolist()

# %%
quietest_hour_BTC = max(set(quiet_hours_BTC), key=quiet_hours.count)
quietest_hour_BTC
# Out:
# 10

# %%
import pylab as pl

N, bins, patches = pl.hist(quiet_hours_BTC, bins = [x for x in range(24)])
pl.title("BTC Lowest-Voume Time")
pl.xlabel("Hour of day")
pl.ylabel("Count")
pl.xticks([x for x in range(24)])

jet = pl.get_cmap('jet', len(patches))

for i in range(len(patches)):
    patches[i].set_facecolor(jet(i))

# %%
df_ETH = pd.read_pickle('ETH-USD-60.pkl')
df_ETH['date'] = pd.to_datetime(df_ETH['time'],unit='s').dt.date
df_ETH['datetime'] = pd.to_datetime(df_ETH['time'],unit='s').dt.time
df_ETH['hour'] = pd.to_datetime(df_ETH['time'],unit='s').dt.hour
Daily_ETH = df_ETH.groupby('date')

quiet_hours_ETH = Daily_ETH.apply(lambda x: x.loc[x['volume'] == x['volume'].min()])['hour'].values.tolist()
quietest_hour_ETH = max(set(quiet_hours_ETH), key=quiet_hours.count)
quietest_hour_ETH
# Out:
# 10

# %%
N, bins, patches = pl.hist(quiet_hours_ETH, bins = [x for x in range(24)])
pl.title("ETH Lowest-Voume Time")
pl.xlabel("Hour of day")
pl.ylabel("Count")
pl.xticks([x for x in range(24)])

jet = pl.get_cmap('jet', len(patches))

for i in range(len(patches)):
    patches[i].set_facecolor(jet(i))

# %%
df_LTC = pd.read_pickle('LTC-USD-60.pkl')
df_LTC['date'] = pd.to_datetime(df_LTC['time'],unit='s').dt.date
df_LTC['datetime'] = pd.to_datetime(df_LTC['time'],unit='s').dt.time
df_LTC['hour'] = pd.to_datetime(df_LTC['time'],unit='s').dt.hour
Daily_LTC = df_LTC.groupby('date')

quiet_hours_LTC = Daily_LTC.apply(lambda x: x.loc[x['volume'] == x['volume'].min()])['hour'].values.tolist()
quietest_hour_LTC = max(set(quiet_hours_LTC), key=quiet_hours.count)
quietest_hour_LTC
# Out:
# 10

# %%
N, bins, patches = pl.hist(quiet_hours_LTC, bins = [x for x in range(24)])
pl.title("LTC Lowest-Voume Time")
pl.xlabel("Hour of day")
pl.ylabel("Count")
pl.xticks([x for x in range(24)])

jet = pl.get_cmap('jet', len(patches))

for i in range(len(patches)):
    patches[i].set_facecolor(jet(i))

# %%
df_BCH = pd.read_pickle('BCH-USD-60.pkl')
df_BCH['date'] = pd.to_datetime(df_BCH['time'],unit='s').dt.date
df_BCH['datetime'] = pd.to_datetime(df_BCH['time'],unit='s').dt.time
df_BCH['hour'] = pd.to_datetime(df_BCH['time'],unit='s').dt.hour
Daily_BCH = df_BCH.groupby('date')

quiet_hours_BCH = Daily_BCH.apply(lambda x: x.loc[x['volume'] == x['volume'].min()])['hour'].values.tolist()
quietest_hour_BCH = max(set(quiet_hours_BCH), key=quiet_hours.count)
quietest_hour_BCH
# Out:
# 10

# %%
N, bins, patches = pl.hist(quiet_hours_BCH, bins = [x for x in range(24)])
pl.title("BCH Lowest-Voume Time")
pl.xlabel("Hour of day")
pl.ylabel("Count")
pl.xticks([x for x in range(24)])

jet = pl.get_cmap('jet', len(patches))

for i in range(len(patches)):
    patches[i].set_facecolor(jet(i))
